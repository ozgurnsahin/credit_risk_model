# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('df_train.csv',low_memory=False, index_col= 0)
df_test = pd.read_csv('df_test.csv',low_memory=False, index_col= 0)

# %%
df_train_target = pd.read_csv('df_target_train.csv',low_memory=False)
df_test_target = pd.read_csv('df_target_test.csv',low_memory=False)

# %%
df_test_target.shape
# Out:
# (100000, 1)

# %%
print(df_train_target.shape, df_train.shape)
# Out:
# (400000, 1) (400000, 294)

# %%
inputs_train_with_ref_cat = df_train.loc[: ,['grade:A',
       'grade:B', 'grade:C', 'grade:D', 'grade:E', 'grade:F', 'grade:G',
       'sub_grade:A1', 'sub_grade:A2', 'sub_grade:A3', 'sub_grade:A4',
       'sub_grade:A5', 'sub_grade:B1', 'sub_grade:B2', 'sub_grade:B3',
       'sub_grade:B4', 'sub_grade:B5', 'sub_grade:C1', 'sub_grade:C2',
       'sub_grade:C3', 'sub_grade:C4', 'sub_grade:C5', 'sub_grade:D1',
       'sub_grade:D2', 'sub_grade:D3', 'sub_grade:D4', 'sub_grade:D5',
       'sub_grade:E1', 'sub_grade:E2', 'sub_grade:E3', 'sub_grade:E4',
       'sub_grade:E5', 'sub_grade:F1', 'sub_grade:F2', 'sub_grade:F3',
       'sub_grade:F4', 'sub_grade:F5', 'sub_grade:G1', 'sub_grade:G2',
       'sub_grade:G3', 'sub_grade:G4', 'sub_grade:G5',
       'home_ownership:ANY', 'home_ownership:MORTGAGE',
       'home_ownership:OWN', 'home_ownership:RENT',
       'verification_status:Not Verified',
       'verification_status:Source Verified',
       'verification_status:Verified', 'loan_status:Charged Off',
       'loan_status:Current', 'loan_status:Default',
       'loan_status:Fully Paid', 'loan_status:In Grace Period',
       'loan_status:Late (16-30 days)', 'loan_status:Late (31-120 days)',
       'purpose:car', 'purpose:credit_card', 'purpose:debt_consolidation',
       'purpose:home_improvement', 'purpose:house',
       'purpose:major_purchase', 'purpose:medical', 'purpose:moving',
       'purpose:other', 'purpose:renewable_energy',
       'purpose:small_business', 'purpose:vacation', 'purpose:wedding',
       'addr_state:AK', 'addr_state:AL', 'addr_state:AR', 'addr_state:AZ',
       'addr_state:CA', 'addr_state:CO', 'addr_state:CT', 'addr_state:DC',
       'addr_state:DE', 'addr_state:FL', 'addr_state:GA', 'addr_state:HI',
       'addr_state:ID', 'addr_state:IL', 'addr_state:IN', 'addr_state:KS',
       'addr_state:KY', 'addr_state:LA', 'addr_state:MA', 'addr_state:MD',
       'addr_state:ME', 'addr_state:MI', 'addr_state:MN', 'addr_state:MO',
       'addr_state:MS', 'addr_state:MT', 'addr_state:NC', 'addr_state:ND',
       'addr_state:NE', 'addr_state:NH', 'addr_state:NJ', 'addr_state:NM',
       'addr_state:NV', 'addr_state:NY', 'addr_state:OH', 'addr_state:OK',
       'addr_state:OR', 'addr_state:PA', 'addr_state:RI', 'addr_state:SC',
       'addr_state:SD', 'addr_state:TN', 'addr_state:TX', 'addr_state:UT',
       'addr_state:VA', 'addr_state:VT', 'addr_state:WA', 'addr_state:WI',
       'addr_state:WV', 'addr_state:WY', 'initial_list_status:f',
       'initial_list_status:w', 'addr_state:VT_ID_WV_ME', 'term:36',
       'term:60', 'emp_length_int:0', 'emp_length_int:1',
       'emp_length_int:2_3_4', 'emp_length_int:5', 'emp_length_int:6',
       'emp_length_int:7_8', 'emp_length_int:9', 'emp_length_int:10',
       'int_rate_factor', 'int_rate:<9.59', 'int_rate:9.59-19.006',
       'int_rate:19.006-19.982', 'int_rate:19.982-27.566',
       'int_rate:27.566-28.422', 'int_rate:>28.422', 'annual_inc_factor',
       'annual_inc:<97572', 'annual_inc:>97572',
       'mths_since_last_delinq:missing', 'mths_since_last_delinq:<31.64',
       'mths_since_last_delinq:31.64-76.84',
       'mths_since_last_delinq:>76.84']]

# %%
ref_cats = ['grade:G','sub_grade:G5','home_ownership:RENT','verification_status:Not Verified','loan_status:Charged Off','purpose:other','addr_state:UT','initial_list_status:w','emp_length_int:0','int_rate:>28.422','annual_inc:>97572','mths_since_last_delinq:missing']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_cats,axis=1)

# %%
inputs_train = inputs_train.drop(['annual_inc_factor','int_rate_factor'], axis=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
reg.fit(inputs_train, df_train_target)
# Out:
# /home/albatrosfirst/credit_risk_model/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-1.61839324])

# %%
reg.coef_
# Out:
# array([[ 3.27700435e-01, -2.27532910e-01, -3.79934939e-01,
#         -3.10731940e-01, -2.46224841e-01, -5.65658905e-01,
#          4.24749623e-01,  2.56715496e-01,  5.52044493e-02,
#         -1.43414241e-01, -2.65554892e-01,  1.43844382e-03,
#          1.19447070e-01, -9.68828802e-02,  1.53799902e-02,
#         -2.66915533e-01,  1.71675417e-02, -5.16753152e-02,
#         -9.40350270e-02, -1.27713231e-01, -1.23678908e-01,
#         -9.40818389e-02, -1.06857609e-01, -1.49717056e-01,
#          6.74675749e-02, -2.75430118e-02,  8.91410294e-02,
#         -9.40412901e-03, -1.59410861e-01, -6.15611265e-02,
#         -1.04989754e-01, -2.77165778e-01, -8.37208668e-02,
#         -4.30284644e-02, -7.91724600e-02, -8.25713355e-02,
#         -1.51709186e-01, -1.50636122e-03, -4.80499798e-04,
#         -1.75085690e-02,  3.31605148e-02, -6.15756988e-02,
#         -1.72449845e-01, -3.83225296e-01, -4.56813288e-01,
#          1.58244852e+01, -4.87263888e-02,  1.12332627e+01,
# ...

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns=['feature_name'], data= feature_name)
summary_table['coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index +1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()

# %%
summary_table
# Out:
#                            feature_name  coefficients
# 0                             Intercept     -1.618393
# 1                               grade:A      0.327700
# 2                               grade:B     -0.227533
# 3                               grade:C     -0.379935
# 4                               grade:D     -0.310732
# ..                                  ...           ...
# 128              int_rate:27.566-28.422     -0.024400
# 129                   annual_inc:<97572     -0.444224
# 130       mths_since_last_delinq:<31.64      0.036350
# 131  mths_since_last_delinq:31.64-76.84      0.000633
# 132       mths_since_last_delinq:>76.84      0.050857
#
# [133 rows x 2 columns]

# %% [markdown]
# ***Building Logistic Regression Model with-P Values***

# %%
import scipy.stats as stat

class LogisticRegression_with_pvalues:
    def __init__(self, *args, **kwargs):
          self.model = LogisticRegression(*args,**kwargs)
        
    def fit(self, X, Y):
        self.model.fit(X, Y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X/denom).T, X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x))*2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_pvalues()

# %%
reg.fit(inputs_train, df_train_target)
# Out:
# /home/albatrosfirst/credit_risk_model/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_5400/30325308.py:13: RuntimeWarning: invalid value encountered in sqrt
#   sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))

# %%
summary_table = pd.DataFrame(columns=['feature_name'], data= feature_name)
summary_table['coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index +1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            feature_name  coefficients
# 0                             Intercept     -1.618393
# 1                               grade:A      0.327700
# 2                               grade:B     -0.227533
# 3                               grade:C     -0.379935
# 4                               grade:D     -0.310732
# ..                                  ...           ...
# 128              int_rate:27.566-28.422     -0.024400
# 129                   annual_inc:<97572     -0.444224
# 130       mths_since_last_delinq:<31.64      0.036350
# 131  mths_since_last_delinq:31.64-76.84      0.000633
# 132       mths_since_last_delinq:>76.84      0.050857
#
# [133 rows x 2 columns]

# %%
p_values = reg.p_values

# %%
p_values = np.append(np.nan , np.array(p_values))
summary_table['p_values'] = p_values

# %%
pd.options.display.max_rows = None
summary_table
# Out:
#                             feature_name  coefficients       p_values
# 0                              Intercept     -1.618393            NaN
# 1                                grade:A      0.327700   1.000000e+00
# 2                                grade:B     -0.227533   1.000000e+00
# 3                                grade:C     -0.379935   9.999999e-01
# 4                                grade:D     -0.310732            NaN
# 5                                grade:E     -0.246225            NaN
# 6                                grade:F     -0.565659   1.000000e+00
# 7                           sub_grade:A1      0.424750   1.000000e+00
# 8                           sub_grade:A2      0.256715   1.000000e+00
# 9                           sub_grade:A3      0.055204   1.000000e+00
# 10                          sub_grade:A4     -0.143414   1.000000e+00
# 11                          sub_grade:A5     -0.265555   1.000000e+00
# ...

# %%
inputs_train_with_ref_cat = df_train.loc[: , ['grade:A',
       'grade:B', 'grade:C', 'grade:D', 'grade:E', 'grade:F', 'grade:G',
       'home_ownership:ANY', 'home_ownership:MORTGAGE',
       'home_ownership:OWN', 'home_ownership:RENT',
       'verification_status:Not Verified',
       'verification_status:Source Verified',
       'verification_status:Verified', 'loan_status:Charged Off',
       'loan_status:Current', 'loan_status:Default',
       'loan_status:Fully Paid', 'loan_status:In Grace Period',
       'loan_status:Late (16-30 days)', 'loan_status:Late (31-120 days)',
       'purpose:car', 'purpose:credit_card', 'purpose:debt_consolidation',
       'purpose:home_improvement', 'purpose:house',
       'purpose:major_purchase', 'purpose:medical', 'purpose:moving',
       'purpose:other', 'purpose:renewable_energy',
       'purpose:small_business', 'purpose:vacation', 'purpose:wedding',
       'addr_state:AK', 'addr_state:AL', 'addr_state:AR', 'addr_state:AZ',
       'addr_state:CA', 'addr_state:CO', 'addr_state:CT', 'addr_state:DC',
       'addr_state:DE', 'addr_state:FL', 'addr_state:GA', 'addr_state:HI',
       'addr_state:ID', 'addr_state:IL', 'addr_state:IN', 'addr_state:KS',
       'addr_state:KY', 'addr_state:LA', 'addr_state:MA', 'addr_state:MD',
       'addr_state:ME', 'addr_state:MI', 'addr_state:MN', 'addr_state:MO',
       'addr_state:MS', 'addr_state:MT', 'addr_state:NC', 'addr_state:ND',
       'addr_state:NE', 'addr_state:NH', 'addr_state:NJ', 'addr_state:NM',
       'addr_state:NV', 'addr_state:NY', 'addr_state:OH', 'addr_state:OK',
       'addr_state:OR', 'addr_state:PA', 'addr_state:RI', 'addr_state:SC',
       'addr_state:SD', 'addr_state:TN', 'addr_state:TX', 'addr_state:UT',
       'addr_state:VA', 'addr_state:VT', 'addr_state:WA', 'addr_state:WI',
       'addr_state:WV', 'addr_state:WY', 'initial_list_status:f',
       'initial_list_status:w', 'addr_state:VT_ID_WV_ME', 'term:36',
       'term:60', 'emp_length_int:0', 'emp_length_int:1',
       'emp_length_int:2_3_4', 'emp_length_int:5', 'emp_length_int:6',
       'emp_length_int:7_8', 'emp_length_int:9', 'emp_length_int:10',
       'int_rate_factor', 'int_rate:<9.59', 'int_rate:9.59-19.006',
       'int_rate:19.006-19.982', 'int_rate:19.982-27.566',
       'int_rate:27.566-28.422', 'int_rate:>28.422', 'annual_inc_factor',
       'annual_inc:<97572', 'annual_inc:>97572',
       'mths_since_last_delinq:missing', 'mths_since_last_delinq:<31.64',
       'mths_since_last_delinq:31.64-76.84',
       'mths_since_last_delinq:>76.84']]

# %%
ref_cats = ['grade:G','home_ownership:RENT','verification_status:Not Verified','loan_status:Charged Off','purpose:other','addr_state:UT','initial_list_status:w','emp_length_int:0','int_rate:>28.422','annual_inc:>97572','mths_since_last_delinq:missing']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_cats,axis=1)
inputs_train = inputs_train.drop(['annual_inc_factor','int_rate_factor'], axis=1)
inputs_train.head()
# Out:
#      grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  home_ownership:ANY  \
# id
# NaN        1        0        0        0        0        0                   0
# NaN        0        1        0        0        0        0                   0
# NaN        1        0        0        0        0        0                   0
# NaN        1        0        0        0        0        0                   0
# NaN        0        1        0        0        0        0                   0
#
#      home_ownership:MORTGAGE  home_ownership:OWN  \
# id
# NaN                        1                   0
# NaN                        0                   0
# NaN                        1                   0
# NaN                        1                   0
# NaN                        1                   0
#
#      verification_status:Source Verified  verification_status:Verified  \
# id
# NaN                                    1                             0
# ...

# %%
reg2 = LogisticRegression_with_pvalues()
reg2.fit(inputs_train, df_train_target)
# Out:
# /home/albatrosfirst/credit_risk_model/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns=['feature_name'], data= feature_name)
summary_table['coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index +1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            feature_name  coefficients
# 0                             Intercept     -1.618393
# 1                               grade:A      0.288041
# 2                               grade:B     -0.239608
# 3                               grade:C     -0.308552
# 4                               grade:D     -0.220026
# 5                               grade:E     -0.273900
# 6                               grade:F     -0.614081
# 7                    home_ownership:ANY      0.033227
# 8               home_ownership:MORTGAGE     -0.040319
# 9                    home_ownership:OWN     -0.191590
# 10  verification_status:Source Verified     -0.439442
# 11         verification_status:Verified     -0.477200
# 12                  loan_status:Current     15.636086
# 13                  loan_status:Default     -0.047901
# 14               loan_status:Fully Paid     11.357543
# 15          loan_status:In Grace Period      8.286627
# ...

# %%
p_values = np.append(np.nan , np.array(reg2.p_values))
summary_table['p_values'] = p_values

# %% [markdown]
# ***Model Validation***

# %%
inputs_test_with_ref_cat = df_test.loc[:, ['grade:A',
       'grade:B', 'grade:C', 'grade:D', 'grade:E', 'grade:F', 'grade:G',
       'home_ownership:ANY', 'home_ownership:MORTGAGE',
       'home_ownership:OWN', 'home_ownership:RENT',
       'verification_status:Not Verified',
       'verification_status:Source Verified',
       'verification_status:Verified', 'loan_status:Charged Off',
       'loan_status:Current', 'loan_status:Default',
       'loan_status:Fully Paid', 'loan_status:In Grace Period',
       'loan_status:Late (16-30 days)', 'loan_status:Late (31-120 days)',
       'purpose:car', 'purpose:credit_card', 'purpose:debt_consolidation',
       'purpose:home_improvement', 'purpose:house',
       'purpose:major_purchase', 'purpose:medical', 'purpose:moving',
       'purpose:other', 'purpose:renewable_energy',
       'purpose:small_business', 'purpose:vacation', 'purpose:wedding',
       'addr_state:AK', 'addr_state:AL', 'addr_state:AR', 'addr_state:AZ',
       'addr_state:CA', 'addr_state:CO', 'addr_state:CT', 'addr_state:DC',
       'addr_state:DE', 'addr_state:FL', 'addr_state:GA', 'addr_state:HI',
       'addr_state:ID', 'addr_state:IL', 'addr_state:IN', 'addr_state:KS',
       'addr_state:KY', 'addr_state:LA', 'addr_state:MA', 'addr_state:MD',
       'addr_state:ME', 'addr_state:MI', 'addr_state:MN', 'addr_state:MO',
       'addr_state:MS', 'addr_state:MT', 'addr_state:NC', 'addr_state:ND',
       'addr_state:NE', 'addr_state:NH', 'addr_state:NJ', 'addr_state:NM',
       'addr_state:NV', 'addr_state:NY', 'addr_state:OH', 'addr_state:OK',
       'addr_state:OR', 'addr_state:PA', 'addr_state:RI', 'addr_state:SC',
       'addr_state:SD', 'addr_state:TN', 'addr_state:TX', 'addr_state:UT',
       'addr_state:VA', 'addr_state:VT', 'addr_state:WA', 'addr_state:WI',
       'addr_state:WV', 'addr_state:WY', 'initial_list_status:f',
       'initial_list_status:w', 'addr_state:VT_ID_WV_ME', 'term:36',
       'term:60', 'emp_length_int:0', 'emp_length_int:1',
       'emp_length_int:2_3_4', 'emp_length_int:5', 'emp_length_int:6',
       'emp_length_int:7_8', 'emp_length_int:9', 'emp_length_int:10',
       'int_rate_factor', 'int_rate:<9.59', 'int_rate:9.59-19.006',
       'int_rate:19.006-19.982', 'int_rate:19.982-27.566',
       'int_rate:27.566-28.422', 'int_rate:>28.422', 'annual_inc_factor',
       'annual_inc:<97572', 'annual_inc:>97572',
       'mths_since_last_delinq:missing', 'mths_since_last_delinq:<31.64',
       'mths_since_last_delinq:31.64-76.84',
       'mths_since_last_delinq:>76.84']]

# %%
inputs_test_with_ref_cat.columns
# Out:
# Index(['grade:A', 'grade:B', 'grade:C', 'grade:D', 'grade:E', 'grade:F',
#        'grade:G', 'home_ownership:ANY', 'home_ownership:MORTGAGE',
#        'home_ownership:OWN',
#        ...
#        'int_rate:19.982-27.566', 'int_rate:27.566-28.422', 'int_rate:>28.422',
#        'annual_inc_factor', 'annual_inc:<97572', 'annual_inc:>97572',
#        'mths_since_last_delinq:missing', 'mths_since_last_delinq:<31.64',
#        'mths_since_last_delinq:31.64-76.84', 'mths_since_last_delinq:>76.84'],
#       dtype='object', length=111)

# %%
input_test = inputs_test_with_ref_cat.drop(ref_cats, axis = 1)
input_test = input_test.drop(['int_rate_factor', 'annual_inc_factor'], axis = 1)
input_test.head()
# Out:
#      grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  home_ownership:ANY  \
# id
# NaN        0        1        0        0        0        0                   0
# NaN        1        0        0        0        0        0                   0
# NaN        0        0        0        1        0        0                   0
# NaN        0        1        0        0        0        0                   0
# NaN        0        0        0        1        0        0                   0
#
#      home_ownership:MORTGAGE  home_ownership:OWN  \
# id
# NaN                        0                   0
# NaN                        0                   0
# NaN                        1                   0
# NaN                        1                   0
# NaN                        0                   0
#
#      verification_status:Source Verified  verification_status:Verified  \
# id
# NaN                                    1                             0
# ...

# %%
y_hat_test = reg2.model.predict(input_test)

# %%
y_hat_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(100000,))

# %%
y_hat_test_prob = reg2.model.predict_proba(input_test)

# %%
y_hat_test_prob
# Out:
# array([[5.88505001e-06, 9.99994115e-01],
#        [2.45742238e-06, 9.99997543e-01],
#        [2.76633693e-06, 9.99997234e-01],
#        ...,
#        [5.18854731e-06, 9.99994811e-01],
#        [9.12339109e-06, 9.99990877e-01],
#        [1.33875912e-05, 9.99986612e-01]], shape=(100000, 2))

# %%
y_hat_test_prob[: ][: ,1]
# Out:
# array([0.99999411, 0.99999754, 0.99999723, ..., 0.99999481, 0.99999088,
#        0.99998661], shape=(100000,))

# %%
y_hat_test_prob = y_hat_test_prob[: ][: ,1]

# %%
y_hat_test_prob
# Out:
# array([0.99999411, 0.99999754, 0.99999723, ..., 0.99999481, 0.99999088,
#        0.99998661], shape=(100000,))

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, roc_curve

# %%
acc = accuracy_score(df_test_target,y_hat_test)
acc
# Out:
# 1.0

# %%
roc_score = roc_auc_score(df_test_target,y_hat_test)
roc_score
# Out:
# np.float64(1.0)

# %%
matrix = confusion_matrix(df_test_target,y_hat_test)
matrix
# Out:
# array([[ 2841,     0],
#        [    0, 97159]])
