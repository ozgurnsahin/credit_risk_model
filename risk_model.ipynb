# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ***Loading Data and Preprocessing***

# %%
df = pd.read_csv('loan.csv',low_memory=False, nrows=1000000)

# %%
copy_of_data = df.copy()

# %%
pd.options.display.max_columns = None

# %%
df
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0      NaN        NaN       2500         2500           2500.0   36 months
# 1      NaN        NaN      30000        30000          30000.0   60 months
# 2      NaN        NaN       5000         5000           5000.0   36 months
# 3      NaN        NaN       4000         4000           4000.0   36 months
# 4      NaN        NaN      30000        30000          30000.0   60 months
# ...     ..        ...        ...          ...              ...         ...
# 999995 NaN        NaN      12000        12000          12000.0   36 months
# 999996 NaN        NaN       3000         3000           3000.0   36 months
# 999997 NaN        NaN      16000        16000          16000.0   60 months
# 999998 NaN        NaN      14000        14000          14000.0   60 months
# 999999 NaN        NaN      15000        15000          15000.0   36 months
#
#         int_rate  installment grade sub_grade                   emp_title  \
# 0          13.56        84.92     C        C1                        Chef
# 1          18.94       777.23     D        D2                 Postmaster
# 2          17.97       180.69     D        D1              Administrative
# 3          18.94       146.51     D        D2               IT Supervisor
# 4          16.14       731.78     C        C4                    Mechanic
# ...          ...          ...   ...       ...                         ...
# 999995     12.05       398.86     C        C1            Systems Engineer
# 999996      6.24        91.60     A        A2                  ACCOUNTING
# 999997      9.99       339.88     B        B3                 ACCOUNT REP
# 999998     19.99       370.84     E        E4                         LPN
# 999999      9.17       478.19     B        B2  Equipment Maint Supervisor
#
#        emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0       10+ years           RENT     55000.0        Not Verified  Dec-2018
# 1       10+ years       MORTGAGE     90000.0     Source Verified  Dec-2018
# 2         6 years       MORTGAGE     59280.0     Source Verified  Dec-2018
# 3       10+ years       MORTGAGE     92000.0     Source Verified  Dec-2018
# 4       10+ years       MORTGAGE     57250.0        Not Verified  Dec-2018
# ...           ...            ...         ...                 ...       ...
# 999995   < 1 year           RENT     75000.0     Source Verified  Nov-2015
# 999996  10+ years       MORTGAGE     53000.0        Not Verified  Nov-2015
# 999997    6 years       MORTGAGE    100000.0        Not Verified  Nov-2015
# 999998   < 1 year       MORTGAGE     35000.0     Source Verified  Nov-2015
# 999999    5 years           RENT    100000.0     Source Verified  Nov-2015
#
#         loan_status pymnt_plan  url desc             purpose  \
# 0           Current          n  NaN  NaN  debt_consolidation
# 1           Current          n  NaN  NaN  debt_consolidation
# 2           Current          n  NaN  NaN  debt_consolidation
# 3           Current          n  NaN  NaN  debt_consolidation
# 4           Current          n  NaN  NaN  debt_consolidation
# ...             ...        ...  ...  ...                 ...
# 999995   Fully Paid          n  NaN  NaN         credit_card
# 999996   Fully Paid          n  NaN  NaN  debt_consolidation
# 999997   Fully Paid          n  NaN  NaN  debt_consolidation
# 999998  Charged Off          n  NaN  NaN  debt_consolidation
# 999999   Fully Paid          n  NaN  NaN  debt_consolidation
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 0            Debt consolidation    109xx         NY  18.24            0
# 1            Debt consolidation    713xx         LA  26.52            0
# 2            Debt consolidation    490xx         MI  10.51            0
# 3            Debt consolidation    985xx         WA  16.74            0
# 4            Debt consolidation    212xx         MD  26.35            0
# ...                         ...      ...        ...    ...          ...
# 999995  Credit card refinancing    553xx         MN  18.35            1
# 999996       Debt consolidation    786xx         TX  27.81            0
# 999997       Debt consolidation    600xx         IL  17.68            0
# 999998       Debt consolidation    469xx         IN  34.70            0
# 999999       Debt consolidation    950xx         CA   6.96            0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0              Apr-2001             1.0                     NaN
# 1              Jun-1987             0.0                    71.0
# 2              Apr-2011             0.0                     NaN
# 3              Feb-2006             0.0                     NaN
# 4              Dec-2000             0.0                     NaN
# ...                 ...             ...                     ...
# 999995         Jun-2006             2.0                    21.0
# 999996         Apr-1999             0.0                     NaN
# 999997         Aug-1999             0.0                    55.0
# 999998         Mar-2002             1.0                    41.0
# 999999         Mar-2005             0.0                     NaN
#
#         mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                         45.0         9        1       4341        10.3
# 1                         75.0        13        1      12315        24.2
# 2                          NaN         8        0       4599        19.1
# 3                          NaN        10        0       5468        78.1
# 4                          NaN        12        0        829         3.6
# ...                        ...       ...      ...        ...         ...
# 999995                     NaN         8        0       5206        32.5
# 999996                     NaN        10        0      10775        46.4
# 999997                     NaN        20        0      15588        40.2
# 999998                     NaN        12        0      20951        56.8
# 999999                     NaN         7        0       8866        53.4
#
#         total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0              34                   w    2386.02        2386.02    167.020000
# 1              44                   w   29387.75       29387.75   1507.110000
# 2              13                   w    4787.21        4787.21    353.890000
# 3              13                   w    3831.93        3831.93    286.710000
# 4              26                   w   29339.02       29339.02   1423.210000
# ...           ...                 ...        ...            ...           ...
# 999995         12                   w       0.00           0.00  12389.660000
# 999996         22                   f       0.00           0.00   3295.220019
# 999997         32                   w       0.00           0.00  18978.830889
# 999998         26                   f       0.00           0.00   3692.030000
# 999999         16                   w       0.00           0.00  17203.119176
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0                167.02           113.98          53.04                 0.0
# 1               1507.11           612.25         894.86                 0.0
# 2                353.89           212.79         141.10                 0.0
# 3                286.71           168.07         118.64                 0.0
# 4               1423.21           660.98         762.23                 0.0
# ...                 ...              ...            ...                 ...
# 999995         12389.66         12000.00         389.66                 0.0
# 999996          3295.22          3000.00         295.22                 0.0
# 999997         18978.83         16000.00        2978.83                 0.0
# 999998          3692.03          1324.43        2087.60                 0.0
# 999999         17203.12         15000.00        2203.12                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0              0.0                      0.0     Feb-2019            84.92
# 1              0.0                      0.0     Feb-2019           777.23
# 2              0.0                      0.0     Feb-2019           180.69
# 3              0.0                      0.0     Feb-2019           146.51
# 4              0.0                      0.0     Feb-2019           731.78
# ...            ...                      ...          ...              ...
# 999995         0.0                      0.0     Feb-2016         11656.21
# 999996         0.0                      0.0     Nov-2018            91.30
# 999997         0.0                      0.0     Mar-2018          9619.54
# 999998       280.0                     50.4     Aug-2016           370.84
# 999999         0.0                      0.0     Nov-2018           477.93
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0          Mar-2019           Feb-2019                           0
# 1          Mar-2019           Feb-2019                           0
# 2          Mar-2019           Feb-2019                           0
# 3          Mar-2019           Feb-2019                           0
# 4          Mar-2019           Feb-2019                           0
# ...             ...                ...                         ...
# 999995          NaN           Oct-2018                           0
# 999996          NaN           Feb-2018                           0
# 999997          NaN           Jan-2019                           0
# 999998          NaN           Feb-2019                           0
# 999999          NaN           Feb-2019                           0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 0                               NaN            1       Individual
# 1                               NaN            1       Individual
# 2                               NaN            1       Individual
# 3                               NaN            1       Individual
# 4                               NaN            1       Individual
# ...                             ...          ...              ...
# 999995                          NaN            1       Individual
# 999996                          NaN            1       Individual
# 999997                          NaN            1       Individual
# 999998                          NaN            1       Individual
# 999999                          NaN            1       Individual
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0                    NaN        NaN                       NaN               0
# 1                    NaN        NaN                       NaN               0
# 2                    NaN        NaN                       NaN               0
# 3                    NaN        NaN                       NaN               0
# 4                    NaN        NaN                       NaN               0
# ...                  ...        ...                       ...             ...
# 999995               NaN        NaN                       NaN               0
# 999996               NaN        NaN                       NaN               0
# 999997               NaN        NaN                       NaN               0
# 999998               NaN        NaN                       NaN               0
# 999999               NaN        NaN                       NaN               0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0                  0        16901          2.0          2.0          1.0
# 1               1208       321915          4.0          4.0          2.0
# 2                  0       110299          0.0          1.0          0.0
# 3                686       305049          1.0          5.0          3.0
# 4                  0       116007          3.0          5.0          3.0
# ...              ...          ...          ...          ...          ...
# 999995             0        42047          NaN          NaN          NaN
# 999996             0        57606          NaN          NaN          NaN
# 999997          1110        47768          NaN          NaN          NaN
# 999998             0        30022          NaN          NaN          NaN
# 999999          1206        13618          NaN          NaN          NaN
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0               2.0                 2.0       12560.0     69.0          2.0
# 1               3.0                 3.0       87153.0     88.0          4.0
# 2               2.0                14.0        7150.0     72.0          0.0
# 3               5.0                 5.0       30683.0     68.0          0.0
# 4               5.0                 4.0       28845.0     89.0          2.0
# ...             ...                 ...           ...      ...          ...
# 999995          NaN                 NaN           NaN      NaN          NaN
# 999996          NaN                 NaN           NaN      NaN          NaN
# 999997          NaN                 NaN           NaN      NaN          NaN
# 999998          NaN                 NaN           NaN      NaN          NaN
# 999999          NaN                 NaN           NaN      NaN          NaN
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0               7.0      2137.0      28.0             42000     1.0
# 1               5.0       998.0      57.0             50800     2.0
# 2               2.0         0.0      35.0             24100     1.0
# 3               0.0      3761.0      70.0              7000     2.0
# 4               4.0       516.0      54.0             23100     1.0
# ...             ...         ...       ...               ...     ...
# 999995          NaN         NaN       NaN             16000     NaN
# 999996          NaN         NaN       NaN             23200     NaN
# 999997          NaN         NaN       NaN             38800     NaN
# 999998          NaN         NaN       NaN             36900     NaN
# 999999          NaN         NaN       NaN             16600     NaN
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0              11.0           2.0                     9       1878.0
# 1              15.0           2.0                    10      24763.0
# 2               5.0           0.0                     4      18383.0
# 3               4.0           3.0                     5      30505.0
# 4               0.0           0.0                     9       9667.0
# ...             ...           ...                   ...          ...
# 999995          NaN           NaN                     3       5256.0
# 999996          NaN           NaN                     1       5761.0
# 999997          NaN           NaN                     2       2514.0
# 999998          NaN           NaN                     5       2502.0
# 999999          NaN           NaN                     1       1945.0
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0              34360.0      5.9                         0            0
# 1              13761.0      8.3                         0            0
# 2              13800.0      0.0                         0            0
# 3               1239.0     75.2                         0            0
# 4               8471.0      8.9                         0            0
# ...                ...      ...                       ...          ...
# 999995          7986.0     36.1                         0            0
# 999996          9942.0     52.0                         0            0
# 999997         16512.0     48.6                         0            0
# 999998          4843.0     75.5                         0            0
# 999999           139.0     98.0                         0            0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0                    140.0                   212                      1
# 1                    163.0                   378                      4
# 2                     87.0                    92                     15
# 3                     62.0                   154                     64
# 4                     53.0                   216                      2
# ...                    ...                   ...                    ...
# 999995                55.0                   113                      3
# 999996               155.0                   199                     35
# 999997               174.0                   195                      6
# 999998               127.0                   164                      7
# 999999               124.0                   128                      7
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                    1         0                   1.0
# 1                    3         3                   4.0
# 2                   14         2                  77.0
# 3                    5         3                  64.0
# 4                    2         2                   2.0
# ...                ...       ...                   ...
# 999995               3         0                  25.0
# 999996              16         1                  35.0
# 999997               6         0                   6.0
# 999998               7         0                  15.0
# 999999               7         0                  99.0
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                            NaN                    2.0
# 1                            NaN                    4.0
# 2                            NaN                   14.0
# 3                            NaN                    5.0
# 4                            NaN                   13.0
# ...                          ...                    ...
# 999995                      21.0                    3.0
# 999996                       NaN                    NaN
# 999997                      55.0                    6.0
# 999998                      42.0                    6.0
# 999999                       NaN                    7.0
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                                  NaN                      0               2
# 1                                  NaN                      0               2
# 2                                  NaN                      0               0
# 3                                  NaN                      0               1
# 4                                  NaN                      0               2
# ...                                ...                    ...             ...
# 999995                            21.0                      0               3
# 999996                             NaN                      0               5
# 999997                            55.0                      2               7
# 999998                            41.0                      0               3
# 999999                             NaN                      0               2
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                     5            3          3         16              7
# 1                     4            4          9         27              8
# 2                     3            3          3          4              6
# 3                     2            1          2          7              2
# 4                     2            3          8          9              6
# ...                 ...          ...        ...        ...            ...
# 999995                4            3          4          6              5
# 999996                6            5         10          6              7
# 999997                7           10         16          8             15
# 999998                7            3         10          4              8
# 999999                5            2          5          6              6
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0                  18                    5         9               0.0
# 1                  14                    4        13               0.0
# 2                   7                    3         8               0.0
# 3                   3                    2        10               0.0
# 4                  15                    2        12               0.0
# ...               ...                  ...       ...               ...
# 999995              6                    4         8               0.0
# 999996             14                    6        10               0.0
# 999997             22                    7        19               0.0
# 999998             22                    7        12               0.0
# 999999             10                    5         7               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0                  0                   0                   3           100.0
# 1                  0                   0                   6            95.0
# 2                  0                   0                   0           100.0
# 3                  0                   0                   3           100.0
# 4                  0                   0                   5            92.3
# ...              ...                 ...                 ...             ...
# 999995             0                   0                   3            75.0
# 999996             0                   0                   0           100.0
# 999997             0                   0                   2            90.6
# 999998             0                   0                   3            80.8
# 999999             0                   0                   1           100.0
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                    0.0                     1          0            60124
# 1                    0.0                     1          0           372872
# 2                    0.0                     0          0           136927
# 3                  100.0                     0          0           385183
# 4                    0.0                     0          0           157548
# ...                  ...                   ...        ...              ...
# 999995               0.0                     0          0            67651
# 999996              60.0                     0          0            93379
# 999997              30.0                     0          0            99369
# 999998              66.7                     0          0            59951
# 999999             100.0                     0          0            30123
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                   16901           36500                       18124
# 1                   99468           15000                       94072
# 2                   11749           13800                       10000
# 3                   36151            5000                       44984
# 4                   29674            9300                       32332
# ...                   ...             ...                         ...
# 999995              42047           12500                       51651
# 999996              57606           20700                       70179
# 999997              47768           32100                       60569
# 999998              30022           19800                       23051
# 999999              13618            7100                       13523
#
#         revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0                   NaN                      NaN                     NaN
# 1                   NaN                      NaN                     NaN
# 2                   NaN                      NaN                     NaN
# 3                   NaN                      NaN                     NaN
# 4                   NaN                      NaN                     NaN
# ...                 ...                      ...                     ...
# 999995              NaN                      NaN                     NaN
# 999996              NaN                      NaN                     NaN
# 999997              NaN                      NaN                     NaN
# 999998              NaN                      NaN                     NaN
# 999999              NaN                      NaN                     NaN
#
#         sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0                    NaN               NaN                 NaN
# 1                    NaN               NaN                 NaN
# 2                    NaN               NaN                 NaN
# 3                    NaN               NaN                 NaN
# 4                    NaN               NaN                 NaN
# ...                  ...               ...                 ...
# 999995               NaN               NaN                 NaN
# 999996               NaN               NaN                 NaN
# 999997               NaN               NaN                 NaN
# 999998               NaN               NaN                 NaN
# 999999               NaN               NaN                 NaN
#
#         sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ...                     ...                    ...
# 999995                  NaN                    NaN
# 999996                  NaN                    NaN
# 999997                  NaN                    NaN
# 999998                  NaN                    NaN
# 999999                  NaN                    NaN
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 999995                               NaN                                 NaN
# 999996                               NaN                                 NaN
# 999997                               NaN                                 NaN
# 999998                               NaN                                 NaN
# 999999                               NaN                                 NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                       NaN             N           NaN
# 1                                       NaN             N           NaN
# 2                                       NaN             N           NaN
# 3                                       NaN             N           NaN
# 4                                       NaN             N           NaN
# ...                                     ...           ...           ...
# 999995                                  NaN             N           NaN
# 999996                                  NaN             N           NaN
# 999997                                  NaN             N           NaN
# 999998                                  NaN             N           NaN
# 999999                                  NaN             N           NaN
#
#        hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0                  NaN             NaN            NaN              NaN
# 1                  NaN             NaN            NaN              NaN
# 2                  NaN             NaN            NaN              NaN
# 3                  NaN             NaN            NaN              NaN
# 4                  NaN             NaN            NaN              NaN
# ...                ...             ...            ...              ...
# 999995             NaN             NaN            NaN              NaN
# 999996             NaN             NaN            NaN              NaN
# 999997             NaN             NaN            NaN              NaN
# 999998             NaN             NaN            NaN              NaN
# 999999             NaN             NaN            NaN              NaN
#
#        hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                      NaN               NaN                     NaN
# 1                      NaN               NaN                     NaN
# 2                      NaN               NaN                     NaN
# 3                      NaN               NaN                     NaN
# 4                      NaN               NaN                     NaN
# ...                    ...               ...                     ...
# 999995                 NaN               NaN                     NaN
# 999996                 NaN               NaN                     NaN
# 999997                 NaN               NaN                     NaN
# 999998                 NaN               NaN                     NaN
# 999999                 NaN               NaN                     NaN
#
#         hardship_length  hardship_dpd hardship_loan_status  \
# 0                   NaN           NaN                  NaN
# 1                   NaN           NaN                  NaN
# 2                   NaN           NaN                  NaN
# 3                   NaN           NaN                  NaN
# 4                   NaN           NaN                  NaN
# ...                 ...           ...                  ...
# 999995              NaN           NaN                  NaN
# 999996              NaN           NaN                  NaN
# 999997              NaN           NaN                  NaN
# 999998              NaN           NaN                  NaN
# 999999              NaN           NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 999995                                         NaN
# 999996                                         NaN
# 999997                                         NaN
# 999998                                         NaN
# 999999                                         NaN
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# ...                                ...                           ...
# 999995                             NaN                           NaN
# 999996                             NaN                           NaN
# 999997                             NaN                           NaN
# 999998                             NaN                           NaN
# 999999                             NaN                           NaN
#
#        disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0                     Cash                    N                       NaN
# 1                     Cash                    N                       NaN
# 2                     Cash                    N                       NaN
# 3                     Cash                    N                       NaN
# 4                     Cash                    N                       NaN
# ...                    ...                  ...                       ...
# 999995                Cash                    N                       NaN
# 999996                Cash                    N                       NaN
# 999997                Cash                    N                       NaN
# 999998                Cash                    Y                  Jan-2019
# 999999                Cash                    N                       NaN
#
#        settlement_status settlement_date  settlement_amount  \
# 0                    NaN             NaN                NaN
# 1                    NaN             NaN                NaN
# 2                    NaN             NaN                NaN
# 3                    NaN             NaN                NaN
# 4                    NaN             NaN                NaN
# ...                  ...             ...                ...
# 999995               NaN             NaN                NaN
# 999996               NaN             NaN                NaN
# 999997               NaN             NaN                NaN
# 999998            ACTIVE        Jan-2019            6734.94
# 999999               NaN             NaN                NaN
#
#         settlement_percentage  settlement_term
# 0                         NaN              NaN
# 1                         NaN              NaN
# 2                         NaN              NaN
# 3                         NaN              NaN
# 4                         NaN              NaN
# ...                       ...              ...
# 999995                    NaN              NaN
# 999996                    NaN              NaN
# 999997                    NaN              NaN
# 999998                   50.0             18.0
# 999999                    NaN              NaN
#
# [1000000 rows x 145 columns]

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade       emp_title emp_length  \
# 0     13.56        84.92     C        C1            Chef  10+ years
# 1     18.94       777.23     D        D2     Postmaster   10+ years
# 2     17.97       180.69     D        D1  Administrative    6 years
# 3     18.94       146.51     D        D2   IT Supervisor  10+ years
# 4     16.14       731.78     C        C4        Mechanic  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0           RENT     55000.0        Not Verified  Dec-2018     Current
# 1       MORTGAGE     90000.0     Source Verified  Dec-2018     Current
# 2       MORTGAGE     59280.0     Source Verified  Dec-2018     Current
# 3       MORTGAGE     92000.0     Source Verified  Dec-2018     Current
# 4       MORTGAGE     57250.0        Not Verified  Dec-2018     Current
#
#   pymnt_plan  url desc             purpose               title zip_code  \
# 0          n  NaN  NaN  debt_consolidation  Debt consolidation    109xx
# 1          n  NaN  NaN  debt_consolidation  Debt consolidation    713xx
# 2          n  NaN  NaN  debt_consolidation  Debt consolidation    490xx
# 3          n  NaN  NaN  debt_consolidation  Debt consolidation    985xx
# 4          n  NaN  NaN  debt_consolidation  Debt consolidation    212xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NY  18.24            0         Apr-2001             1.0
# 1         LA  26.52            0         Jun-1987             0.0
# 2         MI  10.51            0         Apr-2011             0.0
# 3         WA  16.74            0         Feb-2006             0.0
# 4         MD  26.35            0         Dec-2000             0.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                    45.0         9        1
# 1                    71.0                    75.0        13        1
# 2                     NaN                     NaN         8        0
# 3                     NaN                     NaN        10        0
# 4                     NaN                     NaN        12        0
#
#    revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0       4341        10.3         34                   w    2386.02
# 1      12315        24.2         44                   w   29387.75
# 2       4599        19.1         13                   w    4787.21
# 3       5468        78.1         13                   w    3831.93
# 4        829         3.6         26                   w   29339.02
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        2386.02       167.02           167.02           113.98
# 1       29387.75      1507.11          1507.11           612.25
# 2        4787.21       353.89           353.89           212.79
# 3        3831.93       286.71           286.71           168.07
# 4       29339.02      1423.21          1423.21           660.98
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          53.04                 0.0         0.0                      0.0
# 1         894.86                 0.0         0.0                      0.0
# 2         141.10                 0.0         0.0                      0.0
# 3         118.64                 0.0         0.0                      0.0
# 4         762.23                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Feb-2019            84.92     Mar-2019           Feb-2019
# 1     Feb-2019           777.23     Mar-2019           Feb-2019
# 2     Feb-2019           180.69     Mar-2019           Feb-2019
# 3     Feb-2019           146.51     Mar-2019           Feb-2019
# 4     Feb-2019           731.78     Mar-2019           Feb-2019
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                           0                          NaN            1
# 1                           0                          NaN            1
# 2                           0                          NaN            1
# 3                           0                          NaN            1
# 4                           0                          NaN            1
#
#   application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 0       Individual               NaN        NaN                       NaN
# 1       Individual               NaN        NaN                       NaN
# 2       Individual               NaN        NaN                       NaN
# 3       Individual               NaN        NaN                       NaN
# 4       Individual               NaN        NaN                       NaN
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 0               0             0        16901          2.0          2.0
# 1               0          1208       321915          4.0          4.0
# 2               0             0       110299          0.0          1.0
# 3               0           686       305049          1.0          5.0
# 4               0             0       116007          3.0          5.0
#
#    open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0          1.0          2.0                 2.0       12560.0     69.0
# 1          2.0          3.0                 3.0       87153.0     88.0
# 2          0.0          2.0                14.0        7150.0     72.0
# 3          3.0          5.0                 5.0       30683.0     68.0
# 4          3.0          5.0                 4.0       28845.0     89.0
#
#    open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0          2.0          7.0      2137.0      28.0             42000     1.0
# 1          4.0          5.0       998.0      57.0             50800     2.0
# 2          0.0          2.0         0.0      35.0             24100     1.0
# 3          0.0          0.0      3761.0      70.0              7000     2.0
# 4          2.0          4.0       516.0      54.0             23100     1.0
#
#    total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0         11.0           2.0                     9       1878.0
# 1         15.0           2.0                    10      24763.0
# 2          5.0           0.0                     4      18383.0
# 3          4.0           3.0                     5      30505.0
# 4          0.0           0.0                     9       9667.0
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0         34360.0      5.9                         0            0
# 1         13761.0      8.3                         0            0
# 2         13800.0      0.0                         0            0
# 3          1239.0     75.2                         0            0
# 4          8471.0      8.9                         0            0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               140.0                   212                      1
# 1               163.0                   378                      4
# 2                87.0                    92                     15
# 3                62.0                   154                     64
# 4                53.0                   216                      2
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0               1         0                   1.0                       NaN
# 1               3         3                   4.0                       NaN
# 2              14         2                  77.0                       NaN
# 3               5         3                  64.0                       NaN
# 4               2         2                   2.0                       NaN
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    2.0                             NaN
# 1                    4.0                             NaN
# 2                   14.0                             NaN
# 3                    5.0                             NaN
# 4                   13.0                             NaN
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                      0               2                5            3
# 1                      0               2                4            4
# 2                      0               0                3            3
# 3                      0               1                2            1
# 4                      0               2                2            3
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0          3         16              7             18                    5
# 1          9         27              8             14                    4
# 2          3          4              6              7                    3
# 3          2          7              2              3                    2
# 4          8          9              6             15                    2
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0         9               0.0             0                   0
# 1        13               0.0             0                   0
# 2         8               0.0             0                   0
# 3        10               0.0             0                   0
# 4        12               0.0             0                   0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                   3           100.0               0.0                     1
# 1                   6            95.0               0.0                     1
# 2                   0           100.0               0.0                     0
# 3                   3           100.0             100.0                     0
# 4                   5            92.3               0.0                     0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          0            60124              16901           36500
# 1          0           372872              99468           15000
# 2          0           136927              11749           13800
# 3          0           385183              36151            5000
# 4          0           157548              29674            9300
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                       18124              NaN                      NaN
# 1                       94072              NaN                      NaN
# 2                       10000              NaN                      NaN
# 3                       44984              NaN                      NaN
# 4                       32332              NaN                      NaN
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                 NaN                  NaN                    NaN
# 2                 NaN                  NaN                    NaN
# 3                 NaN                  NaN                    NaN
# 4                 NaN                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N           NaN
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                  NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df.columns.values
# Out:
# array(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d',
#        'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m',
#        'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths',
#        'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_inq', 'mths_since_recent_revol_delinq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats',
#        'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m',
#        'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75',
#        'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim',
#        'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit', 'revol_bal_joint',
#        'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths',
#        'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util',
#        'sec_app_open_act_il', 'sec_app_num_rev_accts',
#        'sec_app_chargeoff_within_12_mths',
#        'sec_app_collections_12_mths_ex_med',
#        'sec_app_mths_since_last_major_derog', 'hardship_flag',
#        'hardship_type', 'hardship_reason', 'hardship_status',
#        'deferral_term', 'hardship_amount', 'hardship_start_date',
#        'hardship_end_date', 'payment_plan_start_date', 'hardship_length',
#        'hardship_dpd', 'hardship_loan_status',
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status',
#        'settlement_date', 'settlement_amount', 'settlement_percentage',
#        'settlement_term'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Columns: 145 entries, id to settlement_term
# dtypes: float64(70), int64(39), object(36)
# memory usage: 1.1+ GB

# %%
df['term'].info()
df['grade'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000000 entries, 0 to 999999
# Series name: term
# Non-Null Count    Dtype
# --------------    -----
# 1000000 non-null  object
# dtypes: object(1)
# memory usage: 7.6+ MB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000000 entries, 0 to 999999
# Series name: grade
# Non-Null Count    Dtype
# --------------    -----
# 1000000 non-null  object
# dtypes: object(1)
# memory usage: 7.6+ MB

# %%
df['emp_length'].unique()
# Out:
# array(['10+ years', '6 years', '4 years', '< 1 year', '2 years',
#        '9 years', nan, '5 years', '3 years', '7 years', '1 year',
#        '8 years'], dtype=object)

# %%
df['emp_length_int'] = df['emp_length'].str.replace('+ years','')
df['emp_length_int'] = df['emp_length_int'].str.replace('< 1 year',str(0))
df['emp_length_int'] = df['emp_length_int'].str.replace(' years','')
df['emp_length_int'] = df['emp_length_int'].str.replace(' year','')
df['emp_length_int'] = df['emp_length_int'].str.replace('NaN',str(0))

# %%
df['emp_length_int'].unique()
# Out:
# array(['10', '6', '4', '0', '2', '9', nan, '5', '3', '7', '1', '8'],
#       dtype=object)

# %%
df['emp_length_int'] = pd.to_numeric(df['emp_length_int'])

# %%
df['term_int'] = df['term'].str.replace(' months','')
df['term_int'] = df['term_int'].str.strip()

# %%
df['term_int'] = pd.to_numeric(df['term_int'])

# %%
df['term_int'].unique()
# Out:
# array([36, 60])

# %%
df['earliest_cr_line']
# Out:
# 0         Apr-2001
# 1         Jun-1987
# 2         Apr-2011
# 3         Feb-2006
# 4         Dec-2000
#             ...
# 999995    Jun-2006
# 999996    Apr-1999
# 999997    Aug-1999
# 999998    Mar-2002
# 999999    Mar-2005
# Name: earliest_cr_line, Length: 1000000, dtype: object

# %%
df['earliest_cr_line_date'] = pd.to_datetime(df['earliest_cr_line'], format = '%b-%Y')
